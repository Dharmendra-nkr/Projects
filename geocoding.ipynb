# %%
import pandas as pd

# %%
df=pd.read_csv(r'C:\MyFILES\DV-project\Zomato\address_zomato.csv')

# %% [markdown]
# #### Geocoding

# %%
df
# Out:
#                                                 address
# 0     942, 21st Main Road, 2nd Stage, Banashankari, ...  \
# 1     2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2     1112, Next to KIMS Medical College, 17th Cross...
# 3     1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4     10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                 ...
# 9494  Unit 04-01, 4th floor, Ascendas Park Square Ma...
# 9495      107/PA, ITPL Main Road, Whitefield, Bangalore
# 9496  Cessna Business Park, Sarjapur ÃÂÃÂÃÂÃÂ...
# 9497  44, Kodigehalli to Hoodi Main Road, Mahadevapu...
# 9498  139/C1, Next To GR Tech Park, Pattandur Agraha...
#
#                                              name  rate  votes
# 0                                           Jalsa   4.1    775  \
# 1                                  Spice Elephant   4.1    787
# 2                                 San Churro Cafe   3.8    918
# ...

# %%
from geopy.geocoders import Nominatim
geolocator= Nominatim(user_agent = 'nkrdharmendra@gmail.com')

location =geolocator.geocode()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 4
#       1 from geopy.geocoders import Nominatim
#       2 geolocator= Nominatim(user_agent = 'nkrdharmendra@gmail.com')
# ----> 4 location =geolocator.geocode()
#
# TypeError: Nominatim.geocode() missing 1 required positional argument: 'query'
